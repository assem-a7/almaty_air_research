# %%
import sys
from pathlib import Path

# Find project root (folder that contains "src")
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT =", PROJECT_ROOT)
print("src exists =", (PROJECT_ROOT / "src").exists())
# Out:
# PROJECT_ROOT = c:\Users\asema\OneDrive\Документы\almaty_air_research
# src exists = True

# %%
from src.data_download import download_pollution_almaty

# %%
pollution_df = download_pollution_almaty(force_source="openmeteo")
pollution_df.head(), pollution_df.shape
# Out:
# (                   datetime  pm25  pm10
#  0 2024-01-01 06:00:00+06:00  21.6  31.2
#  1 2024-01-01 07:00:00+06:00  18.7  27.1
#  2 2024-01-01 08:00:00+06:00  16.5  23.9
#  3 2024-01-01 09:00:00+06:00  14.9  21.6
#  4 2024-01-01 10:00:00+06:00  13.7  19.9,
#  (17544, 3))

# %%
# Standard library imports
import sys
from pathlib import Path
from datetime import datetime

# Project root and src path
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# Third-party imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Local imports
from src.config import (
    CITY, COUNTRY, TIMEZONE, LATITUDE, LONGITUDE,
    START_DATE, END_DATE, RANDOM_SEED,
    RAW_DATA_DIR, INTERIM_DATA_DIR, PROCESSED_DATA_DIR,
    FIGURES_DIR, TABLES_DIR, LOGS_DIR
)
from src.utils import setup_logging, save_df, load_df, get_data_info

# Reproducibility
np.random.seed(RANDOM_SEED)

# Plot settings
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Logging
notebook_name = "01_data_sources_audit"
logger = setup_logging(
    LOGS_DIR / f"{notebook_name}_{datetime.now():%Y%m%d_%H%M%S}.log"
)
logger.info(f"Starting notebook: {notebook_name}")
logger.info(f"City: {CITY}, {COUNTRY}")
logger.info(f"Coordinates: {LATITUDE}, {LONGITUDE}")
logger.info(f"Date range: {START_DATE} to {END_DATE}")

# %%
pollution_df = download_pollution_almaty()
pollution_df.head(), pollution_df.shape
