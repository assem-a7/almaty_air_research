# %% [markdown]
# # Notebook Title
#
# **Purpose:** Brief description of what this notebook does
#
# **Inputs:**
# - List input files/data
#
# **Outputs:**
# - List output files/data
#
# ---

# %% [markdown]
# ## Setup

# %%
# Standard library imports
import sys
from pathlib import Path
from datetime import datetime

# Add src to path
sys.path.append(str(Path.cwd().parent))

# Third-party imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Local imports
from src.config import (
    CITY, COUNTRY, TIMEZONE, LATITUDE, LONGITUDE,
    START_DATE, END_DATE, RANDOM_SEED,
    RAW_DATA_DIR, INTERIM_DATA_DIR, PROCESSED_DATA_DIR,
    FIGURES_DIR, TABLES_DIR, LOGS_DIR
)
from src.utils import setup_logging, save_df, load_df, get_data_info

# Set random seed for reproducibility
np.random.seed(RANDOM_SEED)

# Configure plotting
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Setup logging
notebook_name = Path.cwd().name
logger = setup_logging(LOGS_DIR / f"{notebook_name}_{datetime.now():%Y%m%d_%H%M%S}.log")
logger.info(f"Starting {notebook_name}")
logger.info(f"Analysis for {CITY}, {COUNTRY}")
logger.info(f"Date range: {START_DATE} to {END_DATE}")

# %% [markdown]
# ## Your Analysis Here

# %%
# Your code here
